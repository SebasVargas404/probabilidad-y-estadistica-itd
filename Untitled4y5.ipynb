# %% [markdown]
# <a href="https://colab.research.google.com/github/SebasVargas404/probabilidad-y-estadistica-itd/blob/main/Untitled4y5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)
# vargas fiscal sebastian alejandro
# unidad 1
# practica 4 y 5

# %%
import random

# %%
edades = []
for i in range(100):
  numero_aleatorio = random.randint(18, 70)
  edades.append(numero_aleatorio)

# %%
  print(edades)
# Out:
# [22, 43, 63, 21, 45, 41, 37, 20, 28, 19, 24, 69, 20, 26, 59, 22, 25, 46, 57, 23, 48, 24, 30, 22, 52, 57, 61, 70, 23, 42, 57, 19, 64, 64, 59, 30, 23, 57, 65, 68, 34, 36, 59, 40, 32, 20, 33, 59, 37, 56, 59, 44, 34, 60, 52, 56, 60, 49, 54, 60, 21, 29, 42, 38, 41, 42, 27, 64, 51, 67, 26, 46, 27, 60, 68, 60, 29, 30, 51, 36, 55, 31, 63, 37, 19, 60, 44, 65, 51, 55, 65, 22, 55, 66, 65, 51, 60, 54, 20, 45]

# %%
import pandas as pd

# %%
df = pd.DataFrame(edades, columns=['edades'])
df.head()
# Out:
#    edades
# 0      22
# 1      43
# 2      63
# 3      21
# 4      45

# %%
tabla_frecuencias = df['edades'].value_counts().reset_index()
tabla_frecuencias.columns = ['edades', 'frecuencia']
tabla_frecuencias =  tabla_frecuencias.sort_values(by='edades')
print("tabla de distribuicion de frecuencias: ")
tabla_frecuencias
# Out:
# tabla de distribuicion de frecuencias:
#     edades  frecuencia
# 12      19           3
# 5       20           4
# 15      21           2
# 2       22           4
# 11      23           3
# 24      24           2
# 41      25           1
# 14      26           2
# 25      27           2
# 43      28           1
# 18      29           2
# 10      30           3
# 31      31           1
# 36      32           1
# 35      33           1
# 20      34           2
# 19      36           2
# 13      37           3
# 30      38           1
# 37      40           1
# 27      41           2
# 9       42           3
# 38      43           1
# 29      44           2
# 23      45           2
# 28      46           2
# 40      48           1
# 32      49           1
# 4       51           4
# 26      52           2
# 17      54           2
# 7       55           3
# 16      56           2
# 6       57           4
# 1       59           5
# 0       60           7
# 39      61           1
# 22      63           2
# 8       64           3
# 3       65           4
# 44      66           1
# 33      67           1
# 21      68           2
# 42      69           1
# 34      70           1

# %%
tabla_frecuencias['frecc relativa'] = tabla_frecuencias['frecuencia'] / 100 * 100
tabla_frecuencias
# Out:
#     edades  frecuencia  frecc relativa
# 12      19           3             3.0
# 5       20           4             4.0
# 15      21           2             2.0
# 2       22           4             4.0
# 11      23           3             3.0
# 24      24           2             2.0
# 41      25           1             1.0
# 14      26           2             2.0
# 25      27           2             2.0
# 43      28           1             1.0
# 18      29           2             2.0
# 10      30           3             3.0
# 31      31           1             1.0
# 36      32           1             1.0
# 35      33           1             1.0
# 20      34           2             2.0
# 19      36           2             2.0
# 13      37           3             3.0
# 30      38           1             1.0
# 37      40           1             1.0
# 27      41           2             2.0
# 9       42           3             3.0
# 38      43           1             1.0
# 29      44           2             2.0
# 23      45           2             2.0
# 35      33           1             1.0                    1.0
# 20      34           2             2.0                    2.0
# 19      36           2             2.0                    2.0
# 13      37           3             3.0                    3.0
# 30      38           1             1.0                    1.0
# 37      40           1             1.0                    1.0
# 27      41           2             2.0                    2.0
# 9       42           3             3.0                    3.0
# 38      43           1             1.0                    1.0
# 29      44           2             2.0                    2.0
# 23      45           2             2.0                    2.0
# 28      46           2             2.0                    2.0
# 40      48           1             1.0                    1.0
# 32      49           1             1.0                    1.0
# 4       51           4             4.0                    4.0
# 26      52           2             2.0                    2.0
# 17      54           2             2.0                    2.0
# 7       55           3             3.0                    3.0
# 16      56           2             2.0                    2.0
# 6       57           4             4.0                    4.0
# 1       59           5             5.0                    5.0
# 0       60           7             7.0                    7.0
# 39      61           1             1.0                    1.0
# 22      63           2             2.0                    2.0
# 8       64           3             3.0                    3.0
# 3       65           4             4.0                    4.0
# 44      66           1             1.0                    1.0
# 33      67           1             1.0                    1.0
# 21      68           2             2.0                    2.0
# 42      69           1             1.0                    1.0
# 34      70           1             1.0                    1.0
#
#     frecuencia acumulada
# 12                     3
# 5                      7
# 15                     9
# 2                     13
# 11                    16
# 24                    18
# 41                    19
# 14                    21
# 25                    23
# 43                    24
# 18                    26
# 10                    29
# 31                    30
# 36                    31
# 35                    32
# 20                    34
# 19                    36
# 13                    39
# 30                    40
# 37                    41
# 27                    43
# 9                     46
# 38                    47
# 29                    49
# 23                    51
# 28                    53
# 40                    54
# 32                    55
# 4                     59
# 26                    61
# 17                    63
# 7                     66
# 16                    68
# 6                     72
# 1                     77
# 0                     84
# 39                    85
# 22                    87
# 8                     90
# 3                     94
# 44                    95
# 33                    96
# 21                    98
# 42                    99
# 34                   100

# %%
import math

# %%
print(edades)
# Out:
# [22, 43, 63, 21, 45, 41, 37, 20, 28, 19, 24, 69, 20, 26, 59, 22, 25, 46, 57, 23, 48, 24, 30, 22, 52, 57, 61, 70, 23, 42, 57, 19, 64, 64, 59, 30, 23, 57, 65, 68, 34, 36, 59, 40, 32, 20, 33, 59, 37, 56, 59, 44, 34, 60, 52, 56, 60, 49, 54, 60, 21, 29, 42, 38, 41, 42, 27, 64, 51, 67, 26, 46, 27, 60, 68, 60, 29, 30, 51, 36, 55, 31, 63, 37, 19, 60, 44, 65, 51, 55, 65, 22, 55, 66, 65, 51, 60, 54, 20, 45]

# %%
df = pd.DataFrame({'edad' : edades})
df
# Out:
#     edad
# 0     22
# 1     43
# 2     63
# 3     21
# 4     45
# ..   ...
# 95    51
# 96    60
# 97    54
# 98    20
# 99    45
#
# [100 rows x 1 columns]

# %%
n = len(edades)
k = int(1 + math.log2(100))
print("valor de n = ", n, " \nNumeros de intervalos =", k)
# Out:
# valor de n =  100
# Numeros de intervalos = 7

# %%
tabla_frecuencias = pd.cut(df['edad'], bins=k, include_lowest=True).value_counts().reset_index()
tabla_frecuencias.columns = ['clase', 'frec']
tabla_frecuencias
# Out:
#               clase  frec
# 0  (18.948, 26.286]    21
# 1  (55.429, 62.714]    19
# 2    (62.714, 70.0]    15
# 3  (40.857, 48.143]    13
# 4  (48.143, 55.429]    12
# 5  (26.286, 33.571]    11
# 6  (33.571, 40.857]     9

# %%
tabla_frecuencias['Frec Rel'] = tabla_frecuencias['frec'] / n
tabla_frecuencias['Frec Por'] = tabla_frecuencias['frec'] / n * 100
tabla_frecuencias['Frec Ac'] = tabla_frecuencias['frec'].cumsum()
tabla_frecuencias['Frec Rel Ac'] = tabla_frecuencias['Frec Rel'].cumsum()
tabla_frecuencias['frec por Ac'] = tabla_frecuencias['Frec Por'].cumsum()
tabla_frecuencias
# Out:
#               clase  frec  Frec Rel  Frec Por  Frec Ac  Frec Rel Ac  \
# 0  (18.948, 26.286]    21      0.21      21.0       21         0.21
# 1  (55.429, 62.714]    19      0.19      19.0       40         0.40
# 2    (62.714, 70.0]    15      0.15      15.0       55         0.55
# 3  (40.857, 48.143]    13      0.13      13.0       68         0.68
# 4  (48.143, 55.429]    12      0.12      12.0       80         0.80
# 5  (26.286, 33.571]    11      0.11      11.0       91         0.91
# 6  (33.571, 40.857]     9      0.09       9.0      100         1.00
#
#    frec por Ac
# 0         21.0
# 1         40.0
# 2         55.0
# 3         68.0
# 4         80.0
# 5         91.0
# 6        100.0

# %%
import matplotlib.pyplot as plt
plt.hist(edades,alpha=0.5)
plt.title('Histograma de edades')
# Out:
# Text(0.5, 1.0, 'Histograma de edades')

# %% [markdown]
# PRACTICA 5

# %%
import random
edades2 = []
for i in range(100):
  numero_aleatorio = random.betavariate(1,1)
  edades2.append(numero_aleatorio)
  print(edades2)
  print(edades2)
# Out:
#   File "<ipython-input-33-1058ebad8a02>", line 3
#     for in range(100):
#         ^
# SyntaxError: invalid syntax

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-39-2140624ca71e> in <cell line: 0>()
#       1 fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(9, 4))
# ----> 2 bplot = ax1.boxplots(edades, vert=True, patch_artist=True)
#       3 ax1.set_title('edades Encuesta 1')
#       4 bplot2 = ax2.boxplots(edades2, vert=True, patch_artist=True)
#       5 ax2.set_title('edades encuesta 2')
#
# AttributeError: 'Axes' object has no attribute 'boxplots'

# %%
import random
import pandas as pd
import math
import matplotlib.pyplot as plt
edades = []
for i in range(100):
numero_aleatorio = random.randint(18, 70)
edades.append(numero_aleatorio)
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(9, 4))
bplot1 = ax1.boxplot(edades, vert=True, patch_artist=True)
ax1.set_title('edades Encuesta 1')
edades2 = []
for i in range(100):
numero_aleatorio = random.randint(18,70)
edades2.append(numero_aleatorio)
bplot2 = ax2.boxplot(edades2, vert=True, patch_artist=True)
ax2.set_title('edades encuesta 2')
plt.show()
# Out:
#   File "<ipython-input-41-5ede87c80875>", line 7
#     numero_aleatorio = random.randint(18, 70)
#     ^
# IndentationError: expected an indented block after 'for' statement on line 6
